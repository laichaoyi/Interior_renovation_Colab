# %%
#@markdown # 1. CÀI ĐẶT TOOL
from IPython.display import clear_output
from IPython.display import Javascript
import ipywidgets as widgets
display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 200})'''))
def inf(msg, style, wdth): inf = widgets.Button(description=msg, disabled=True, button_style=style, layout=widgets.Layout(min_width=wdth));display(inf)

# !git clone https://github.com/laichaoyi/Interior_renovation_Colab
# !pip install transformers diffusers numpy torch accelerate gradio
# !wget https://huggingface.co/cyberdelia/CyberRealistic/resolve/main/CyberRealistic_V4.1_FP16.safetensors

clear_output()
inf('\u2714 Done','success', '50px')
# Out:
# Button(button_style='success', description='✔ Done', disabled=True, layout=Layout(min_width='50px'), style=But…

# %%
#@markdown # 2.CHẠY CHƯƠNG TRÌNH
from IPython.display import Javascript
display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 200})'''))
# !python /content/Interior_renovation_Colab/app.py
# Out:
# 2024-03-05 12:09:43.677415: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-05 12:09:43.677485: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-05 12:09:43.678789: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-05 12:09:44.672961: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# No model was supplied, defaulted to Intel/dpt-large and revision e93beec (https://huggingface.co/Intel/dpt-large).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json: 100% 942/942 [00:00<00:00, 4.29MB/s]
# model.safetensors:  60% 818M/1.37G [00:06<00:03, 151MB/s]
